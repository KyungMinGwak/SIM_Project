# %%
import numpy as np
import matplotlib.pyplot as plt
from random import *

# %%
length = 10000 #length of x axis
d = [0]
for i in range(length):
    if(i%4):
        d.append(uniform(1.0,10.0)*i*i*i/10000000000)

plt.plot(d,'o')
plt.show()

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

num_points = 1000
vectors_set = []
for i in range(num_points):
    x1 =np.random.normal(0.0, 0.5)
    y1 = x1*x1*0.1 + 0.3 + np.random.normal(0.0, 0.03) #y = x*0.1 + 0.3의 함수식으로 회귀되는 1000개의 [x, y]데이터를 생성
    vectors_set.append([x1, y1])
    #y = 0.1x + 0.3의 관계에있는 점들에 조금의 변수를 줌 (normal distribution의 편차를 둠))
x_data = [v[0] for v in vectors_set]
y_data = [v[1] for v in vectors_set]

plt.plot(x_data, y_data, "ro", label = "Original Data")
plt.legend()
plt.show()
